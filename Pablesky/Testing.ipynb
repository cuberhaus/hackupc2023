# %%
import json
f = open('../restbai/hackupc2023_restbai__dataset/hackupc2023_restbai__dataset.json', encoding='utf-8')
data = json.load(f)

# %%
from IPython.display import Image

# %%
from PIL import Image
import requests
from io import BytesIO

for i in data['1']['images']:
    response = requests.get(i)
    img = Image.open(BytesIO(response.content))
    display(img)
    print(img.size)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=406x280 at 0x2209A288520>
# (406, 280)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=406x280 at 0x2209A1CADF0>
# (406, 280)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=406x280 at 0x220E2FFCEB0>
# (406, 280)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=406x280 at 0x2209A1DD670>
# (406, 280)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=406x280 at 0x220E2FFCF70>
# (406, 280)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=406x280 at 0x220E301DF40>
# (406, 280)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=406x280 at 0x220E300C5B0>
# (406, 280)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=406x280 at 0x220E2FFCF70>
# (406, 280)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=406x280 at 0x2209A288DC0>
# (406, 280)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=406x280 at 0x220E301DF40>
# (406, 280)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=406x280 at 0x220E2FFCEB0>
# (406, 280)

# %%
img.size
# Out:
# (406, 280)
